# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
DATA = pd.read_csv(r"E:\İbb Analiz Çalışması\Python\DATA.csv")
KONUMLAR = gpd.read_file("E:\İbb Analiz Çalışması\Python\KONUMLAR.gpkg")
DATA2 = KONUMLAR.merge(DATA, on = 'ilce_adi')
DATA2
# Out:
#          ilce_adi                                           geometry  \
# 0          ADALAR  MULTIPOLYGON (((29.05181 40.91486, 29.05181 40...
# 1      ARNAVUTKÖY  MULTIPOLYGON (((28.83302 41.13262, 28.83305 41...
# 2        ATAŞEHİR  MULTIPOLYGON (((29.09809 40.97865, 29.09015 40...
# 3         AVCILAR  MULTIPOLYGON (((28.76738 40.99284, 28.76797 40...
# 4        BAĞCILAR  MULTIPOLYGON (((28.87146 41.03859, 28.87037 41...
# 5    BAHÇELİEVLER  MULTIPOLYGON (((28.85819 41.02142, 28.85933 41...
# 6        BAKIRKÖY  MULTIPOLYGON (((28.76738 40.99284, 28.77344 40...
# 7      BAŞAKŞEHİR  MULTIPOLYGON (((28.81420 41.06014, 28.80922 41...
# 8      BAYRAMPAŞA  MULTIPOLYGON (((28.89410 41.03685, 28.89246 41...
# 9        BEŞİKTAŞ  MULTIPOLYGON (((28.98477 41.04401, 28.98633 41...
# 10         BEYKOZ  MULTIPOLYGON (((29.08069 41.07399, 29.07996 41...
# 11     BEYLİKDÜZÜ  MULTIPOLYGON (((28.69931 40.97375, 28.69931 40...
# 12        BEYOĞLU  MULTIPOLYGON (((28.99400 41.03320, 28.99375 41...
# ...

# %%
DATA2.columns
# Out:
# Index(['ilce_adi', 'geometry', 'Unnamed: 0', 'Unnamed: 0_x',
#        'cok_agir_hasarli_bina_sayisi', 'agir_hasarli_bina_sayisi',
#        'orta_hasarli_bina_sayisi', 'hafif_hasarli_bina_sayisi',
#        'can_kaybi_sayisi', 'agir_yarali_sayisi', 'hastanede_tedavi_sayisi',
#        'hafif_yarali_sayisi', 'dogalgaz_boru_hasari', 'icme_suyu_boru_hasari',
#        'atik_su_boru_hasari', 'gecici_barinma', 'Unnamed: 0_y',
#        'park_ve_yesil_alan', 'Unnamed: 0_x.1', '1980_oncesi',
#        '1980-2000_arasi', '2000_sonrasi', '1-4 kat_arasi', '5-9 kat_arasi',
#        '9-19 kat_arasi', 'Unnamed: 0_y.1', 'hane_halki_buyuklugu',
#        'Unnamed: 0_x.2', 'hastane_sayisi', 'Unnamed: 0_y.2', 'nufus'],
#       dtype='object')

# %% [markdown]
# # Kolonlara göre haritaların çizimleri

# %% [markdown]
# ## Çok Ağır Hasarlı Bina Sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'cok_agir_hasarli_bina_sayisi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Çok Ağır Hasarlı Bina Haritası')
#plt.text(float(28.46773000),float(41.14823900),"{}".format("Çatalca"),size=10)
# Out:
# Text(0.5, 1.0, 'Çok Ağır Hasarlı Bina Haritası')

# %% [markdown]
# ## Ağır Hasarlı Bina Sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'agir_hasarli_bina_sayisi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Ağır Hasarlı Bina Haritası')
# Out:
# Text(0.5, 1.0, 'Ağır Hasarlı Bina Haritası')

# %% [markdown]
# ## Orta Hasarlı Bina Sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'orta_hasarli_bina_sayisi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Orta Hasarlı Bina Haritası')
# Out:
# Text(0.5, 1.0, 'Orta Hasarlı Bina Haritası')

# %% [markdown]
# ## Hafif Hasarlı Bina Sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'hafif_hasarli_bina_sayisi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Hafif Hasarlı Bina Haritası')
# Out:
# Text(0.5, 1.0, 'Hafif Hasarlı Bina Haritası')

# %% [markdown]
# ## Can Kaybı Sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'can_kaybi_sayisi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('CAN KAYBI SAYISI HARİTASI')
plt.text(float(28.93333330),float(41.01666670),"{}".format("FATİH"),size=10)
plt.text(float(28.67534200),float(41.04065800),"{}".format("KÜÇÜKÇEKMECE"),size=10)
plt.text(float(28.75055560),float(40.99750000),"{}".format("BAHÇELİEVLER"),size=10)
# Out:
# Text(28.7505556, 40.9975, 'BAHÇELİEVLER')

# %% [markdown]
# ## Ağır Yaralı Sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'agir_yarali_sayisi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Ağır Yaralı Sayısı Haritası')
#plt.text(float(DATA2.LONGITUDE[i]),float(DATA2.LATITUDE[i]),"{}".format(DATA2.ilce_adi[i]),size=7)
# Out:
# Text(0.5, 1.0, 'Ağır Yaralı Sayısı Haritası')

# %% [markdown]
# ## Hastanede tedavi sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'hastanede_tedavi_sayisi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Hastanede Tedavi Sayısı Haritası')
# Out:
# Text(0.5, 1.0, 'Hastanede Tedavi Sayısı Haritası')

# %% [markdown]
# ## Hafif Yaralı Sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'hafif_yarali_sayisi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Hafif Yaralı Sayısı Haritası')
# Out:
# Text(0.5, 1.0, 'Hafif Yaralı Sayısı Haritası')

# %% [markdown]
# ## Doğalgaz Boru Hasarı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'dogalgaz_boru_hasari', scheme = "Quantiles", k = 5,legend= True)
ax.set_title('Doğalgaz Boru Hasarı Sayısı Haritası')
# Out:
# Text(0.5, 1.0, 'Doğalgaz Boru Hasarı Sayısı Haritası')

# %% [markdown]
# # İçme Suyu Boru Hasarı Sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'icme_suyu_boru_hasari', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('İçme Suyu Boru Hasarı Sayısı Haritası')
# Out:
# Text(0.5, 1.0, 'İçme Suyu Boru Hasarı Sayısı Haritası')

# %% [markdown]
# # Atık Su Boru Hasarı Sayısı

# %%
ax=DATA2.plot(figsize=(15,50) , column= 'atik_su_boru_hasari', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Atık Su Boru Hasarı Sayısı Haritası')
# Out:
# Text(0.5, 1.0, 'Atık Su Boru Hasarı Sayısı Haritası')

# %% [markdown]
# ## Geçici Barınma

# %%
ax=DATA2.plot(figsize=(15,15) , column= 'gecici_barinma', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Geçici Barınma Sayısı Haritası')
# Out:
# Text(0.5, 1.0, 'Geçici Barınma Sayısı Haritası')

# %% [markdown]
# # Park ve Yeşil Alan

# %%
ax=DATA2.plot(figsize=(15,15) , column= 'park_ve_yesil_alan', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Park ve Yeşil Alan Sayısı Haritası')
# Out:
# Text(0.5, 1.0, 'Park ve Yeşil Alan Sayısı Haritası')

# %% [markdown]
# ## 1980 Öncesi Yapılan Binaların Sayısı

# %%
ax=DATA2.plot(figsize=(15,15) , column= '1980_oncesi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('1980 Öncesi Yapılan Binaların Sayısı Haritası')
plt.text(float(28.910119),float(41.018539),"{}".format("FATİH"),size=10)
# Out:
# Text(28.910119, 41.018539, 'FATİH')

# %% [markdown]
# ## 1980-2000 Arası Yapılan Binaların Sayısı

# %%
ax=DATA2.plot(figsize=(15,15) , column= '1980-2000_arasi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('1980-2000 Arası Yapılan Binaların Sayısı Haritası')
# Out:
# Text(0.5, 1.0, '1980-2000 Arası Yapılan Binaların Sayısı Haritası')

# %% [markdown]
# ## 2000 Sonrası Yapılan Binaların Sayısı

# %%
ax=DATA2.plot(figsize=(15,15) , column= '2000_sonrasi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('2000 Sonrası Yapılan Binaların Sayısı Haritası')
# Out:
# Text(0.5, 1.0, '2000 Sonrası Yapılan Binaların Sayısı Haritası')

# %% [markdown]
# ## 1-4 Kat Arası Olan Binaların Sayısı

# %%
ax=DATA2.plot(figsize=(15,15) , column= '1-4 kat_arasi', scheme = "Quantiles", k = 10,legend= True)
ax.set_title('1-4 Kat Arası Olan Binaların Sayısı')
# Out:
# Text(0.5, 1.0, '1-4 Kat Arası Olan Binaların Sayısı')

# %% [markdown]
# ## 5-9 Kat Arası Olan Binaların Sayısı

# %%
ax=DATA2.plot(figsize=(15,15) , column= '5-9 kat_arasi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('5-9 Kat Arası Olan Binaların Sayısı')
# Out:
# Text(0.5, 1.0, '5-9 Kat Arası Olan Binaların Sayısı')

# %% [markdown]
# ## 9-19 Kat Arası Olan Binaların Sayısı

# %%
ax=DATA2.plot(figsize=(15,15) , column= '5-9 kat_arasi', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('5-9 Kat Arası Olan Binaların Sayısı')
# Out:
# Text(0.5, 1.0, '5-9 Kat Arası Olan Binaların Sayısı')

# %% [markdown]
# ## Hane Halkı Büyüklüğü

# %%
ax=DATA2.plot(figsize=(15,15) , column= 'hane_halki_buyuklugu', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Hane Halkı Büyüklüğü Sayısı')
# Out:
# Text(0.5, 1.0, 'Hane Halkı Büyüklüğü Sayısı')

# %% [markdown]
# # Nüfus

# %%
ax=DATA2.plot(figsize=(15,15) , column= 'nufus', scheme = "Quantiles", k = 9,legend= True)
ax.set_title('Nüfus Haritası')
# Out:
# Text(0.5, 1.0, 'Nüfus Haritası')
